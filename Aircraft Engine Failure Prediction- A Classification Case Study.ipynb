# %% [markdown]
# # Aircraft Engine Failure Classification

# %% [markdown]
# The problem is described [here](https://gallery.azure.ai/Experiment/Predictive-Maintenance-Step-2A-of-3-train-and-evaluate-regression-models-2)

# %% [markdown]
# The Dataset can be obtained from [here](https://ti.arc.nasa.gov/tech/dash/groups/pcoe/prognostic-data-repository/)

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
pd.set_option('display.max_columns', None)
import tensorflow as tf
from tensorflow import keras
from sklearn import preprocessing
from sklearn.metrics import recall_score
from keras.models import Sequential
from keras.layers import BatchNormalization
from keras.layers import Dense, Dropout, LSTM, Activation
# %matplotlib inline

# %%
# Data Source https://ti.arc.nasa.gov/tech/dash/groups/pcoe/prognostic-data-repository/

# %%
#df is for train data. dfTest is for test data
df = pd.read_csv('train_FD001.txt', sep=" ", header=None)
df.columns=["unit_id",	"cycles",	"set1",	"set2",	"set3",	"s1",	"s2",	"s3"	,"s4"	,"s5"	,"s6"	,"s7"	,"s8"	,"s9"	,"s10"	,"se11"	,"s12"	,"s13"	,"s14"	,"s15",	"s16"	,"s17",	"s18"	,"s19",	"s20"	,"s21","s22","s23"]
dfTest = pd.read_csv('test_FD001.txt', sep=" ", header=None)
dfTest.columns=["unit_id",	"cycles",	"set1",	"set2",	"set3",	"s1",	"s2",	"s3"	,"s4"	,"s5"	,"s6"	,"s7"	,"s8"	,"s9"	,"s10"	,"se11"	,"s12"	,"s13"	,"s14"	,"s15",	"s16"	,"s17",	"s18"	,"s19",	"s20"	,"s21","s22","s23"]

# %%
df.head()
# Out:
#    unit_id  cycles    set1    set2   set3      s1      s2       s3       s4  \
# 0        1       1 -0.0007 -0.0004  100.0  518.67  641.82  1589.70  1400.60
# 1        1       2  0.0019 -0.0003  100.0  518.67  642.15  1591.82  1403.14
# 2        1       3 -0.0043  0.0003  100.0  518.67  642.35  1587.99  1404.20
# 3        1       4  0.0007  0.0000  100.0  518.67  642.35  1582.79  1401.87
# 4        1       5 -0.0019 -0.0002  100.0  518.67  642.37  1582.85  1406.22
#
#       s5     s6      s7       s8       s9  s10   se11     s12      s13  \
# 0  14.62  21.61  554.36  2388.06  9046.19  1.3  47.47  521.66  2388.02
# 1  14.62  21.61  553.75  2388.04  9044.07  1.3  47.49  522.28  2388.07
# 2  14.62  21.61  554.26  2388.08  9052.94  1.3  47.27  522.42  2388.03
# 3  14.62  21.61  554.45  2388.11  9049.48  1.3  47.13  522.86  2388.08
# 4  14.62  21.61  554.00  2388.06  9055.15  1.3  47.28  522.19  2388.04
#
#        s14     s15   s16  s17   s18    s19    s20      s21  s22  s23
# 0  8138.62  8.4195  0.03  392  2388  100.0  39.06  23.4190  NaN  NaN
# 1  8131.49  8.4318  0.03  392  2388  100.0  39.00  23.4236  NaN  NaN
# 2  8133.23  8.4178  0.03  390  2388  100.0  38.95  23.3442  NaN  NaN
# 3  8133.83  8.3682  0.03  392  2388  100.0  38.88  23.3739  NaN  NaN
# 4  8133.80  8.4294  0.03  393  2388  100.0  38.90  23.4044  NaN  NaN

# %%
dfTest.head()
# Out:
#    unit_id  cycles    set1    set2   set3      s1      s2       s3       s4  \
# 0        1       1  0.0023  0.0003  100.0  518.67  643.02  1585.29  1398.21
# 1        1       2 -0.0027 -0.0003  100.0  518.67  641.71  1588.45  1395.42
# 2        1       3  0.0003  0.0001  100.0  518.67  642.46  1586.94  1401.34
# 3        1       4  0.0042  0.0000  100.0  518.67  642.44  1584.12  1406.42
# 4        1       5  0.0014  0.0000  100.0  518.67  642.51  1587.19  1401.92
#
#       s5     s6      s7       s8       s9  s10   se11     s12      s13  \
# 0  14.62  21.61  553.90  2388.04  9050.17  1.3  47.20  521.72  2388.03
# 1  14.62  21.61  554.85  2388.01  9054.42  1.3  47.50  522.16  2388.06
# 2  14.62  21.61  554.11  2388.05  9056.96  1.3  47.50  521.97  2388.03
# 3  14.62  21.61  554.07  2388.03  9045.29  1.3  47.28  521.38  2388.05
# 4  14.62  21.61  554.16  2388.01  9044.55  1.3  47.31  522.15  2388.03
#
#        s14     s15   s16  s17   s18    s19    s20      s21  s22  s23
# 0  8125.55  8.4052  0.03  392  2388  100.0  38.86  23.3735  NaN  NaN
# 1  8139.62  8.3803  0.03  393  2388  100.0  39.02  23.3916  NaN  NaN
# 2  8130.10  8.4441  0.03  393  2388  100.0  39.08  23.4166  NaN  NaN
# 3  8132.90  8.3917  0.03  391  2388  100.0  39.00  23.3737  NaN  NaN
# 4  8129.54  8.4031  0.03  390  2388  100.0  38.99  23.4130  NaN  NaN

# %%
# sort the dataframe such that engines and their number of cycles are in ascending order
df=df.sort_values(['unit_id', 'cycles'], ascending = [True, True])
dfTest=dfTest.sort_values(['unit_id', 'cycles'], ascending = [True, True])

# %%
# Read data of Remaining useful life(RUL) of engines in test set
dfRUL=pd.read_csv('RUL_FD001.txt', header=None)
dfRUL.columns=["RULmax"]
# associate it with id of engines
dfRUL['unit_id']=np.arange(1,len(dfRUL)+1)
dfRUL.head()
# Out:
#    RULmax  unit_id
# 0     112        1
# 1      98        2
# 2      69        3
# 3      82        4
# 4      91        5

# %%
#merge two dataframe such that we have info of max RUL for each record
#subtract number of cycles from each record from RULmax to get RUL
dfTest=pd.merge(dfTest, dfRUL, on='unit_id')
dfTest['RUL']=(dfTest.groupby(['unit_id'])['cycles'].transform(max)+dfTest['RULmax'])-dfTest['cycles']

# %%
# sensors s22 and s23 has no data so drop them
df=df.drop(['s22','s23'],axis=1)
dfTest=dfTest.drop(['s22','s23'],axis=1)

# %%
df['unit_id'].value_counts().hist(bins=30)
plt.title('Distribution of Number of cycles to failure')
plt.ylabel('count')
plt.xlabel('Number of cycles to failure in Train set');
plt.show()

# %%
dfTest['unit_id'].value_counts().hist(bins=30)
plt.title('Distribution of Number of cycles to failure')
plt.ylabel('count')
plt.xlabel('Number of cycles to failure in Test set');
plt.show()

# %%
#https://stackoverflow.com/questions/15138973/how-to-get-the-number-of-the-most-frequent-value-in-a-column/30063996
#df['unit_id'].value_counts().sort_index()
print("Max count in Train set")
print("id=",df['unit_id'].value_counts().idxmax())
print("value=",df['unit_id'].value_counts().max())
print("\n\nMin count in Train set")
print("id=",df['unit_id'].value_counts().idxmin())
print("value=",df['unit_id'].value_counts().min())
# Out:
# Max count in Train set
# id= 69
# value= 362
#
#
# Min count in Train set
# id= 39
# value= 128

# %%
#df['unit_id'].value_counts().sort_index()
print("Max count in Test set")
print("id=",dfTest['unit_id'].value_counts().idxmax())
print("value=",dfTest['unit_id'].value_counts().max())
print("\n\nMin count in Test set")
print("id=",dfTest['unit_id'].value_counts().idxmin())
print("value=",dfTest['unit_id'].value_counts().min())
# Out:
# Max count in Test set
# id= 49
# value= 303
#
#
# Min count in Test set
# id= 1
# value= 31

# %%
# Engines in test set that has less than 70 records in test set
testCount=dfTest['unit_id'].value_counts().sort_values()
print(testCount[testCount <= 70])
# Out:
# 1     31
# 85    34
# 39    37
# 22    39
# 14    46
# 25    48
# 2     49
# 33    50
# 69    54
# 44    54
# 9     55
# 87    56
# 88    68
# 71    68
# Name: unit_id, dtype: int64

# %%
#1,85,39,22,14,25,2,33,69,44,9,87,71,88 has cycles less than 70. 
#so we remove those records because we will make a sequence of 70 as input to LSTM network
dfTest = dfTest.drop(dfTest[(dfTest['unit_id'] == 1)].index)
dfTest = dfTest.drop(dfTest[(dfTest['unit_id'] == 85)].index)
dfTest = dfTest.drop(dfTest[(dfTest['unit_id'] == 39)].index)
dfTest = dfTest.drop(dfTest[(dfTest['unit_id'] == 22)].index)
dfTest = dfTest.drop(dfTest[(dfTest['unit_id'] == 14)].index)
dfTest = dfTest.drop(dfTest[(dfTest['unit_id'] == 25)].index)
dfTest = dfTest.drop(dfTest[(dfTest['unit_id'] == 2)].index)
dfTest = dfTest.drop(dfTest[(dfTest['unit_id'] == 33)].index)
dfTest = dfTest.drop(dfTest[(dfTest['unit_id'] == 69)].index)
dfTest = dfTest.drop(dfTest[(dfTest['unit_id'] == 44)].index)
dfTest = dfTest.drop(dfTest[(dfTest['unit_id'] == 9)].index)
dfTest = dfTest.drop(dfTest[(dfTest['unit_id'] == 87)].index)
dfTest = dfTest.drop(dfTest[(dfTest['unit_id'] == 71)].index)
dfTest = dfTest.drop(dfTest[(dfTest['unit_id'] == 88)].index)

# %%
# subtract current number of cycles from maximum cycles for each id to get RUL 
df['RUL']=df.groupby(['unit_id'])['cycles'].transform(max)-df['cycles']
dfTest=dfTest.drop("RULmax",axis=1)

# %%
# normalise data to get a range of 0 to 1
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
df.iloc[:,1:-1]=scaler.fit_transform(df.iloc[:,1:-1])
dfTest.iloc[:,1:-1]=scaler.fit_transform(dfTest.iloc[:,1:-1])

# %%
# Some record have zero std dev
df.describe()
# Out:
#             unit_id        cycles          set1          set2     set3  \
# count  20631.000000  20631.000000  20631.000000  20631.000000  20631.0
# mean      51.506568      0.298637      0.499490      0.501959      0.0
# std       29.227633      0.190806      0.125708      0.244218      0.0
# min        1.000000      0.000000      0.000000      0.000000      0.0
# 25%       26.000000      0.141274      0.413793      0.333333      0.0
# 50%       52.000000      0.285319      0.500000      0.500000      0.0
# 75%       77.000000      0.429363      0.586207      0.750000      0.0
# max      100.000000      1.000000      1.000000      1.000000      0.0
#
#             s1            s2            s3            s4       s5  \
# count  20631.0  20631.000000  20631.000000  20631.000000  20631.0
# mean       0.0      0.443052      0.424746      0.450435      0.0
# std        0.0      0.150618      0.133664      0.151935      0.0
# min        0.0      0.000000      0.000000      0.000000      0.0
# 25%        0.0      0.335843      0.331807      0.339467      0.0
# 50%        0.0      0.430723      0.415522      0.435348      0.0
# 75%        0.0      0.539157      0.508829      0.545324      0.0
# max        0.0      1.000000      1.000000      1.000000      0.0
#
#                  s6            s7            s8            s9      s10  \
# count  20631.000000  20631.000000  20631.000000  20631.000000  20631.0
# mean       0.980321      0.566459      0.297957      0.195248      0.0
# std        0.138898      0.142527      0.107554      0.099089      0.0
# min        0.000000      0.000000      0.000000      0.000000      0.0
# 25%        1.000000      0.476651      0.227273      0.140761      0.0
# 50%        1.000000      0.578100      0.287879      0.174684      0.0
# 75%        1.000000      0.669887      0.363636      0.213991      0.0
# max        1.000000      1.000000      1.000000      1.000000      0.0
#
#                se11           s12           s13           s14           s15  \
# count  20631.000000  20631.000000  20631.000000  20631.000000  20631.000000
# mean       0.411410      0.580697      0.317871      0.226095      0.451118
# std        0.158981      0.157261      0.105763      0.098442      0.144306
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.297619      0.484009      0.235294      0.171870      0.346287
# 50%        0.392857      0.594883      0.308824      0.209516      0.438630
# 75%        0.505952      0.695096      0.382353      0.249613      0.541362
# max        1.000000      1.000000      1.000000      1.000000      1.000000
#
#            s16           s17      s18      s19           s20           s21  \
# count  20631.0  20631.000000  20631.0  20631.0  20631.000000  20631.000000
# mean       0.0      0.434221      0.0      0.0      0.524241      0.546127
# std        0.0      0.129064      0.0      0.0      0.140114      0.149476
# min        0.0      0.000000      0.0      0.0      0.000000      0.000000
# 25%        0.0      0.333333      0.0      0.0      0.434109      0.452361
# 50%        0.0      0.416667      0.0      0.0      0.534884      0.557443
# 75%        0.0      0.500000      0.0      0.0      0.627907      0.652582
# max        0.0      1.000000      0.0      0.0      1.000000      1.000000
#
#                 RUL
# count  20631.000000
# mean     107.807862
# std       68.880990
# min        0.000000
# 25%       51.000000
# 50%      103.000000
# 75%      155.000000
# max      361.000000

# %%
# Some record have zero std dev
dfTest.describe()
# Out:
#             unit_id        cycles          set1          set2     set3  \
# count  12407.000000  12407.000000  12407.000000  12407.000000  12407.0
# mean      51.900056      0.260405      0.511903      0.464204      0.0
# std       28.076334      0.175446      0.137669      0.226549      0.0
# min        3.000000      0.000000      0.000000      0.000000      0.0
# 25%       29.000000      0.119205      0.418750      0.307692      0.0
# 50%       52.000000      0.238411      0.512500      0.461538      0.0
# 75%       76.000000      0.377483      0.606250      0.692308      0.0
# max      100.000000      1.000000      1.000000      1.000000      0.0
#
#             s1            s2            s3            s4       s5  \
# count  12407.0  12407.000000  12407.000000  12407.000000  12407.0
# mean       0.0      0.424370      0.494954      0.415337      0.0
# std        0.0      0.127192      0.130529      0.137789      0.0
# min        0.0      0.000000      0.000000      0.000000      0.0
# 25%        0.0      0.334385      0.403532      0.316929      0.0
# 50%        0.0      0.419558      0.492080      0.408413      0.0
# 75%        0.0      0.507886      0.580369      0.503778      0.0
# max        0.0      1.000000      1.000000      1.000000      0.0
#
#                  s6            s7            s8            s9      s10  \
# count  12407.000000  12407.000000  12407.000000  12407.000000  12407.0
# mean       0.969292      0.580854      0.439463      0.254172      0.0
# std        0.172534      0.138554      0.140606      0.088720      0.0
# min        0.000000      0.000000      0.000000      0.000000      0.0
# 25%        1.000000      0.491935      0.341463      0.196963      0.0
# 50%        1.000000      0.588710      0.439024      0.245312      0.0
# 75%        1.000000      0.679435      0.536585      0.297691      0.0
# max        1.000000      1.000000      1.000000      1.000000      0.0
#
#                se11           s12           s13           s14           s15  \
# count  12407.000000  12407.000000  12407.000000  12407.000000  12407.000000
# mean       0.421855      0.541184      0.419124      0.275041      0.445757
# std        0.135672      0.129142      0.133049      0.090743      0.140252
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.321918      0.456621      0.325581      0.216557      0.348035
# 50%        0.417808      0.550228      0.418605      0.269512      0.440556
# 75%        0.506849      0.632420      0.511628      0.322468      0.534995
# max        1.000000      1.000000      1.000000      1.000000      1.000000
#
#            s16           s17      s18      s19           s20           s21  \
# count  12407.0  12407.000000  12407.0  12407.0  12407.000000  12407.000000
# mean       0.0      0.446572      0.0      0.0      0.529699      0.566556
# std        0.0      0.155223      0.0      0.0      0.129782      0.119829
# min        0.0      0.000000      0.0      0.0      0.000000      0.000000
# 25%        0.0      0.375000      0.0      0.0      0.445455      0.489384
# 50%        0.0      0.500000      0.0      0.0      0.536364      0.571975
# 75%        0.0      0.500000      0.0      0.0      0.618182      0.649115
# max        0.0      1.000000      0.0      0.0      1.000000      1.000000
#
#                 RUL
# count  12407.000000
# mean     141.235029
# std       60.418108
# min        7.000000
# 25%       99.000000
# 50%      141.000000
# 75%      181.000000
# max      340.000000

# %%
# Remove record with zero standard deviation
#https://stackoverflow.com/questions/39658574/how-to-drop-columns-which-have-same-values-in-all-rows-via-pandas-or-spark-dataf
df=df.drop(df.std()[(df.std() == 0)].index, axis=1)
dfTest=dfTest.drop(dfTest.std()[(dfTest.std() == 0)].index, axis=1)

# %%
df.shape
# Out:
# (20631, 20)

# %%
dfTest.shape
# Out:
# (12407, 20)

# %% [markdown]
# Note : Seven features are dropped

# %%
ax = df.loc[(df.unit_id == 1)].iloc[:,2:-1].plot(figsize=(16, 5),legend=None)
ax.set_xlabel("All settings and sensors over time in Train Set for Engine ID=1")
# Out:
# Text(0.5, 0, 'All settings and sensors over time in Train Set for Engine ID=1')

# %%
ax = df.loc[(df.unit_id == 19)].iloc[:,2:-1].plot(figsize=(16, 5),legend=None)
ax.set_xlabel("All settings and sensors over time in Train Set for Engine ID=19")
# Out:
# Text(0.5, 0, 'All settings and sensors over time in Train Set for Engine ID=19')

# %%
ax = df.loc[(df.unit_id == 99)].iloc[:,2:-1].plot(figsize=(16, 5),legend=None)
ax.set_xlabel("All settings and sensors over time in Train Set  for Engine ID=99")
# Out:
# Text(0.5, 0, 'All settings and sensors over time in Train Set  for Engine ID=99')

# %%
dfRUL.loc[dfRUL['unit_id']==100]
# Out:
#     RULmax  unit_id
# 99      20      100

# %%
ax = dfTest.loc[(dfTest.unit_id == 100)].iloc[:,2:-1].plot(figsize=(16, 5),legend=None)
ax.set_xlabel("All settings and sensors over time in Test Set for Engine ID=100 with RUL=20")
# Out:
# Text(0.5, 0, 'All settings and sensors over time in Test Set for Engine ID=100 with RUL=20')

# %%
dfRUL.loc[dfRUL['unit_id']==96]
# Out:
#     RULmax  unit_id
# 95     137       96

# %%
ax = dfTest.loc[(dfTest.unit_id == 96)].iloc[:,2:-1].plot(figsize=(16, 5),legend=None)
ax.set_xlabel("All settings and sensors over time in Test Set for Engine ID=96 with RUL=137")
# Out:
# Text(0.5, 0, 'All settings and sensors over time in Test Set for Engine ID=96 with RUL=137')

# %%
# Creating class labels
# 1 when engine is going to fail within next 30 cycles. 0 otherwise
df['label30']=np.where(df['RUL']<30,1,0)
dfTest['label30']=np.where(dfTest['RUL']<30,1,0)

# %%
# 70 timesteps (cycles) to produce one sequence
batch70=70
trainIDs=list(df['unit_id'].unique())
inputNP = np.empty((0,18), int)
labelList=[]

# %%
# Create 3D array from training set for input to LSTM
for id in trainIDs:
    dfTemp=df.loc[df['unit_id']==id]
    start=0
    for i in  range(len(dfTemp)-batch70+1):
        inputNP = np.append(inputNP, dfTemp.iloc[start:start+batch70,1:-2], axis=0)
        labelList.append(dfTemp['label30'].iloc[start+batch70-1])
        start=start+1
trainLSTM = np.reshape(inputNP, (-1,70, 18)) 
trainLSTM=trainLSTM.astype('float32')
trainLSTM.shape
# Out:
# (13731, 70, 18)

# %%
# Array for training labels
trainLabel=np.array(labelList)
trainLabel=np.reshape(trainLabel, (-1,1))
trainLabel.shape
# Out:
# (13731, 1)

# %%
# Create 3D array from testing set for evaluation
testIDs=list(dfTest['unit_id'].unique())
inputNP = np.empty((0,18), int)
labelList=[]

for id in testIDs:
    dfTemp=dfTest.loc[dfTest['unit_id']==id]
    start=0
    for i in  range(len(dfTemp)-batch70+1):
        inputNP = np.append(inputNP, dfTemp.iloc[start:start+batch70,1:-2], axis=0)
        labelList.append(dfTemp['label30'].iloc[start+batch70-1])
        start=start+1
testLSTM = np.reshape(inputNP, (-1,70, 18)) 
testLSTM=testLSTM.astype('float32')
testLSTM.shape
# Out:
# (6473, 70, 18)

# %%
# Array for testing labels
testLabel=np.array(labelList)
testLabel=np.reshape(testLabel, (-1,1))
testLabel.shape
# Out:
# (6473, 1)

# %%
#Modeling
from tensorflow.keras import regularizers
batch70=70
opt = keras.optimizers.Adam(learning_rate=0.004)
model = Sequential()
model.add(LSTM(input_shape=(batch70, trainLSTM.shape[2]),units=100,return_sequences=True,activity_regularizer=tf.keras.regularizers.l2(0.01)))
model.add(LSTM(units=50,return_sequences=False,activity_regularizer=tf.keras.regularizers.l2(0.01)))
model.add(Dense(units=trainLabel.shape[1], activation='sigmoid'))
model.compile(loss='binary_crossentropy', optimizer=opt, metrics=[tf.keras.metrics.Recall()])
print(model.summary())
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_2 (LSTM)               (None, 70, 100)           47600
#
#  lstm_3 (LSTM)               (None, 50)                30200
#
#  dense_1 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 77,851
# Trainable params: 77,851
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
resultTrain=model.fit(trainLSTM, trainLabel, epochs=200, batch_size=256, validation_split=0.25, verbose=1, callbacks = [keras.callbacks.EarlyStopping(monitor='val_loss', min_delta=0, patience=20, verbose=0, mode='auto')])
# Out:
# Epoch 1/200
# 41/41 [==============================] - 24s 459ms/step - loss: 0.4120 - recall_1: 0.6524 - val_loss: 0.2204 - val_recall_1: 0.7725
# Epoch 2/200
# 41/41 [==============================] - 16s 386ms/step - loss: 0.2211 - recall_1: 0.7970 - val_loss: 0.1942 - val_recall_1: 0.8217
# Epoch 3/200
# 41/41 [==============================] - 16s 384ms/step - loss: 0.1845 - recall_1: 0.8338 - val_loss: 0.1648 - val_recall_1: 0.8000
# Epoch 4/200
# 41/41 [==============================] - 15s 372ms/step - loss: 0.1583 - recall_1: 0.8671 - val_loss: 0.4182 - val_recall_1: 0.4638
# Epoch 5/200
# 41/41 [==============================] - 15s 372ms/step - loss: 0.1946 - recall_1: 0.8260 - val_loss: 0.1483 - val_recall_1: 0.9072
# Epoch 6/200
# 41/41 [==============================] - 17s 415ms/step - loss: 0.1351 - recall_1: 0.8848 - val_loss: 0.1364 - val_recall_1: 0.9333
# Epoch 7/200
# 41/41 [==============================] - 16s 388ms/step - loss: 0.1125 - recall_1: 0.9104 - val_loss: 0.0910 - val_recall_1: 0.9203
# Epoch 8/200
# 41/41 [==============================] - 18s 447ms/step - loss: 0.1173 - recall_1: 0.9039 - val_loss: 0.1014 - val_recall_1: 0.8812
# Epoch 9/200
# 41/41 [==============================] - 18s 439ms/step - loss: 0.0966 - recall_1: 0.9208 - val_loss: 0.0841 - val_recall_1: 0.8870
# Epoch 10/200
# 41/41 [==============================] - 17s 418ms/step - loss: 0.0891 - recall_1: 0.9351 - val_loss: 0.0822 - val_recall_1: 0.8855
# Epoch 11/200
# 41/41 [==============================] - 15s 374ms/step - loss: 0.0877 - recall_1: 0.9338 - val_loss: 0.0913 - val_recall_1: 0.9667
# Epoch 12/200
# 41/41 [==============================] - 15s 366ms/step - loss: 0.0822 - recall_1: 0.9420 - val_loss: 0.0765 - val_recall_1: 0.8957
# Epoch 13/200
# 41/41 [==============================] - 17s 415ms/step - loss: 0.0847 - recall_1: 0.9264 - val_loss: 0.0740 - val_recall_1: 0.9130
# Epoch 14/200
# 41/41 [==============================] - 15s 372ms/step - loss: 0.0812 - recall_1: 0.9411 - val_loss: 0.0831 - val_recall_1: 0.9203
# Epoch 15/200
# 41/41 [==============================] - 15s 375ms/step - loss: 0.0745 - recall_1: 0.9472 - val_loss: 0.1064 - val_recall_1: 0.8304
# Epoch 16/200
# 41/41 [==============================] - 16s 380ms/step - loss: 0.0693 - recall_1: 0.9463 - val_loss: 0.0704 - val_recall_1: 0.9594
# Epoch 17/200
# 41/41 [==============================] - 16s 381ms/step - loss: 0.0852 - recall_1: 0.9281 - val_loss: 0.0789 - val_recall_1: 0.8754
# Epoch 18/200
# 41/41 [==============================] - 15s 376ms/step - loss: 0.0747 - recall_1: 0.9338 - val_loss: 0.0781 - val_recall_1: 0.8681
# Epoch 19/200
# 41/41 [==============================] - 15s 377ms/step - loss: 0.0713 - recall_1: 0.9429 - val_loss: 0.0737 - val_recall_1: 0.9043
# Epoch 20/200
# 41/41 [==============================] - 15s 377ms/step - loss: 0.0680 - recall_1: 0.9472 - val_loss: 0.0650 - val_recall_1: 0.9594
# Epoch 21/200
# 41/41 [==============================] - 16s 385ms/step - loss: 0.0677 - recall_1: 0.9468 - val_loss: 0.0710 - val_recall_1: 0.9464
# Epoch 22/200
# 41/41 [==============================] - 16s 380ms/step - loss: 0.0604 - recall_1: 0.9537 - val_loss: 0.0687 - val_recall_1: 0.9232
# Epoch 23/200
# 41/41 [==============================] - 15s 375ms/step - loss: 0.0749 - recall_1: 0.9407 - val_loss: 0.0737 - val_recall_1: 0.9188
# Epoch 24/200
# 41/41 [==============================] - 15s 379ms/step - loss: 0.0646 - recall_1: 0.9494 - val_loss: 0.0674 - val_recall_1: 0.9014
# Epoch 25/200
# 41/41 [==============================] - 15s 374ms/step - loss: 0.0617 - recall_1: 0.9481 - val_loss: 0.0775 - val_recall_1: 0.9493
# Epoch 26/200
# 41/41 [==============================] - 15s 371ms/step - loss: 0.0626 - recall_1: 0.9541 - val_loss: 0.1258 - val_recall_1: 0.7826
# Epoch 27/200
# 41/41 [==============================] - 16s 390ms/step - loss: 0.0704 - recall_1: 0.9437 - val_loss: 0.0799 - val_recall_1: 0.8710
# Epoch 28/200
# 41/41 [==============================] - 15s 377ms/step - loss: 0.0599 - recall_1: 0.9554 - val_loss: 0.1498 - val_recall_1: 0.7072
# Epoch 29/200
# 41/41 [==============================] - 15s 372ms/step - loss: 0.0759 - recall_1: 0.9368 - val_loss: 0.0713 - val_recall_1: 0.9246
# Epoch 30/200
# 41/41 [==============================] - 15s 373ms/step - loss: 0.0636 - recall_1: 0.9455 - val_loss: 0.0671 - val_recall_1: 0.9174
# Epoch 31/200
# 41/41 [==============================] - 15s 377ms/step - loss: 0.0532 - recall_1: 0.9606 - val_loss: 0.1026 - val_recall_1: 0.8406
# Epoch 32/200
# 41/41 [==============================] - 16s 390ms/step - loss: 0.0602 - recall_1: 0.9515 - val_loss: 0.1409 - val_recall_1: 0.7478
# Epoch 33/200
# 41/41 [==============================] - 16s 384ms/step - loss: 0.0736 - recall_1: 0.9342 - val_loss: 0.0794 - val_recall_1: 0.8623
# Epoch 34/200
# 41/41 [==============================] - 16s 392ms/step - loss: 0.0588 - recall_1: 0.9506 - val_loss: 0.0617 - val_recall_1: 0.9319
# Epoch 35/200
# 41/41 [==============================] - 16s 389ms/step - loss: 0.0520 - recall_1: 0.9632 - val_loss: 0.0571 - val_recall_1: 0.9333
# Epoch 36/200
# 41/41 [==============================] - 17s 414ms/step - loss: 0.0550 - recall_1: 0.9519 - val_loss: 0.0669 - val_recall_1: 0.9565
# Epoch 37/200
# 41/41 [==============================] - 18s 450ms/step - loss: 0.0566 - recall_1: 0.9537 - val_loss: 0.0652 - val_recall_1: 0.9087
# Epoch 38/200
# 41/41 [==============================] - 18s 448ms/step - loss: 0.0554 - recall_1: 0.9494 - val_loss: 0.0680 - val_recall_1: 0.9130
# Epoch 39/200
# 41/41 [==============================] - 18s 444ms/step - loss: 0.0433 - recall_1: 0.9701 - val_loss: 0.0643 - val_recall_1: 0.9493
# Epoch 40/200
# 41/41 [==============================] - 16s 398ms/step - loss: 0.0523 - recall_1: 0.9580 - val_loss: 0.0720 - val_recall_1: 0.9087
# Epoch 41/200
# 41/41 [==============================] - 21s 504ms/step - loss: 0.0464 - recall_1: 0.9645 - val_loss: 0.0539 - val_recall_1: 0.9449
# Epoch 42/200
# 41/41 [==============================] - 17s 428ms/step - loss: 0.0468 - recall_1: 0.9649 - val_loss: 0.0945 - val_recall_1: 0.8536
# Epoch 43/200
# 41/41 [==============================] - 18s 450ms/step - loss: 0.0535 - recall_1: 0.9537 - val_loss: 0.0642 - val_recall_1: 0.9478
# Epoch 44/200
# 41/41 [==============================] - 18s 445ms/step - loss: 0.0449 - recall_1: 0.9667 - val_loss: 0.0791 - val_recall_1: 0.9609
# Epoch 45/200
# 41/41 [==============================] - 16s 397ms/step - loss: 0.0568 - recall_1: 0.9506 - val_loss: 0.0598 - val_recall_1: 0.9275
# Epoch 46/200
# 41/41 [==============================] - 16s 395ms/step - loss: 0.0448 - recall_1: 0.9641 - val_loss: 0.0797 - val_recall_1: 0.9536
# Epoch 47/200
# 41/41 [==============================] - 16s 393ms/step - loss: 0.0595 - recall_1: 0.9476 - val_loss: 0.0699 - val_recall_1: 0.8986
# Epoch 48/200
# 41/41 [==============================] - 16s 398ms/step - loss: 0.0478 - recall_1: 0.9619 - val_loss: 0.0608 - val_recall_1: 0.9217
# Epoch 49/200
# 41/41 [==============================] - 17s 424ms/step - loss: 0.0457 - recall_1: 0.9615 - val_loss: 0.0741 - val_recall_1: 0.9058
# Epoch 50/200
# 41/41 [==============================] - 17s 402ms/step - loss: 0.0559 - recall_1: 0.9554 - val_loss: 0.0778 - val_recall_1: 0.8971
# Epoch 51/200
# 41/41 [==============================] - 15s 376ms/step - loss: 0.0453 - recall_1: 0.9641 - val_loss: 0.0667 - val_recall_1: 0.9174
# Epoch 52/200
# 41/41 [==============================] - 16s 382ms/step - loss: 0.0425 - recall_1: 0.9662 - val_loss: 0.0737 - val_recall_1: 0.8971
# Epoch 53/200
# 41/41 [==============================] - 16s 403ms/step - loss: 0.0435 - recall_1: 0.9641 - val_loss: 0.0595 - val_recall_1: 0.9435
# Epoch 54/200
# 41/41 [==============================] - 16s 392ms/step - loss: 0.0411 - recall_1: 0.9645 - val_loss: 0.2001 - val_recall_1: 0.9928
# Epoch 55/200
# 41/41 [==============================] - 15s 378ms/step - loss: 0.0590 - recall_1: 0.9545 - val_loss: 0.0557 - val_recall_1: 0.9261
# Epoch 56/200
# 41/41 [==============================] - 16s 386ms/step - loss: 0.0437 - recall_1: 0.9662 - val_loss: 0.1610 - val_recall_1: 0.7623
# Epoch 57/200
# 41/41 [==============================] - 16s 397ms/step - loss: 0.0481 - recall_1: 0.9567 - val_loss: 0.0555 - val_recall_1: 0.9333
# Epoch 58/200
# 41/41 [==============================] - 17s 411ms/step - loss: 0.0431 - recall_1: 0.9654 - val_loss: 0.0645 - val_recall_1: 0.9145
# Epoch 59/200
# 41/41 [==============================] - 17s 425ms/step - loss: 0.0434 - recall_1: 0.9649 - val_loss: 0.1162 - val_recall_1: 0.8087
# Epoch 60/200
# 41/41 [==============================] - 16s 385ms/step - loss: 0.0462 - recall_1: 0.9597 - val_loss: 0.1216 - val_recall_1: 0.7957
# Epoch 61/200
# 41/41 [==============================] - 16s 388ms/step - loss: 0.0600 - recall_1: 0.9485 - val_loss: 0.0663 - val_recall_1: 0.9580

# %%
plt.figure(figsize=(8, 8))
plt.title("Learning curve")
plt.plot(resultTrain.history["loss"], label="training loss")
plt.plot(resultTrain.history["val_loss"], label="validation loss")
plt.xlabel("Epochs")
plt.ylabel("log_loss")
plt.legend();

# %%
#Evaluate
resultTest = model.evaluate(testLSTM, testLabel)
# Out:
# 203/203 [==============================] - 7s 33ms/step - loss: 1.1537 - recall_1: 1.0000

# %%
print('Recall =',resultTest[1])
# Out:
# Recall = 1.0
